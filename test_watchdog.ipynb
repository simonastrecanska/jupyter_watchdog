# %% [markdown]
# # Jupyter Watchdog Extension Test
#
# This notebook demonstrates the usage of the `jupyter_watchdog` extension.

# %%
# Load the extension
# %load_ext jupyter_watchdog
# Out:
# Jupyter Watchdog extension loaded. Use %%notify to watch cells.

# %% [markdown]
# ### Test 1: Successful Execution (System Notification)
# Running this cell should trigger a desktop notification after 2 seconds.

# %%
# %%notify system
# import time
# print("Starting task...")
# time.sleep(2)
# print("Finished!")
# Out:
# Starting task...
# Finished!

# %% [markdown]
# ### Test 2: Failed Execution
# Running this cell should trigger a notification indicating failure (❌).

# %%
# %%notify
# time.sleep(1)
# raise ValueError("Something went wrong!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 time.sleep(1)
# ----> 2 raise ValueError("Something went wrong!")
#
# ValueError: Something went wrong!

# %% [markdown]
# ### Test 3: Discord Notification
# **Note:** Ensure you have set your `WEBHOOK_URL` in `jupyter_watchdog.py` before running this, otherwise it will just print a warning.
